# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("depression.csv")
data.head(20)
# Out:
#     Hospt       Treat        Outcome     Time  AcuteT  Age  Gender
# 0       1     Lithium     Recurrence   36.143     211   33       1
# 1       1  Imipramine  No Recurrence  105.143     176   49       1
# 2       1  Imipramine  No Recurrence   74.571     191   50       1
# 3       1     Lithium     Recurrence   49.714     206   29       2
# 4       1     Lithium  No Recurrence   14.429      63   29       1
# 5       1     Placebo     Recurrence    5.000      70   30       2
# 6       1     Lithium  No Recurrence  104.857      55   56       1
# 7       1     Placebo     Recurrence    2.857     512   48       1
# 8       1     Placebo  No Recurrence  102.429     162   22       2
# 9       1     Placebo     Recurrence   55.714     306   61       2
# 10      1  Imipramine  No Recurrence  106.429     165   58       1
# 11      1  Imipramine  No Recurrence  105.143     129   31       1
# 12      1  Imipramine  No Recurrence   83.000     428   44       1
# ...

# %%
data["Age"].hist(bins=40)
# Out:
# <AxesSubplot: >

# %%
sns.set_style('darkgrid')
data["Treat"].hist(bins=3)
# Out:
# <AxesSubplot: >

# %%
data["Gender"].plot(kind="hist", bins=2)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
#sort data by Age(sort by value or columns)
data.sort_values(["Age"]).plot.line(x="Age" , y="Time" , figsize=[4 , 3])
# data[:2].plot.line(x="Age" , y="Time" , figsize=[4 , 4])
# data[:3].plot.line(x="Age" , y="Time" , figsize=[4 , 4])
# data[:4].plot.line(x="Age" , y="Time" , figsize=[4 , 4])
# Out:
# <AxesSubplot: xlabel='Age'>

# %%
data.sort_values(["Age"]).plot.line(x="Age" , y="AcuteT" , figsize=[4, 3])
# Out:
# <AxesSubplot: xlabel='Age'>

# %%
data.sort_values(["Age"]).plot.scatter(x="Age" , y="Time" , figsize=[6, 4])
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Time'>

# %%
data.sort_values(["Age"]).plot.hexbin(x="Age" , y="Time" , figsize=[10, 10] , gridsize=(8,8))
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Time'>
